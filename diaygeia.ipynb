# %% [markdown]
# <a href="https://colab.research.google.com/github/sme2000055-boop/diavgeia-sxoleia/blob/main/diaygeia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import time
import pandas as pd


keywords = [
    "ανακαίνιση σχολείου",
    "ανακαίνιση σχολείων",
    "συντήρηση σχολείου",
    "συντήρηση σχολείων",
    "συντήρηση σχολικών",
    "επισκευή σχολείου",
    "επισκευή σχολείων",
    "ενεργειακή αναβάθμιση σχολ"
]

all_decisions = []
base_url = 'https://diavgeia.gov.gr/luminapi/api/search'

for kw in keywords:
    print(f"--- Συλλογή για: '{kw}' ---")
    page = 0
    size = 100

    while True:
        params = {
            'q': f'subject:"{kw}"',
            'size': size,
            'page': page
        }

        response = requests.get(base_url, params=params)

        if response.status_code != 200:
            print(f"Παράκαμψη {kw} στη σελίδα {page} λόγω σφάλματος {response.status_code}")
            break

        data = response.json()
        decisions = data.get("decisions", [])

        if not decisions:
            break

        all_decisions.extend(decisions)
        print(f"Σελίδα {page} | Τρέχον σύνολο εγγραφών: {len(all_decisions)}")

        page += 1
        time.sleep(0.5)

print(f"\nΤέλος συλλογής! Μαζεύτηκαν συνολικά {len(all_decisions)} εγγραφές (μαζί με διπλότυπα).")
# Out:
# --- Συλλογή για: 'ανακαίνιση σχολείου' ---
# Σελίδα 0 | Τρέχον σύνολο εγγραφών: 35
# --- Συλλογή για: 'ανακαίνιση σχολείων' ---
# Σελίδα 0 | Τρέχον σύνολο εγγραφών: 70
# --- Συλλογή για: 'συντήρηση σχολείου' ---
# Σελίδα 0 | Τρέχον σύνολο εγγραφών: 170
# Σελίδα 1 | Τρέχον σύνολο εγγραφών: 270
# Σελίδα 2 | Τρέχον σύνολο εγγραφών: 370
# Σελίδα 3 | Τρέχον σύνολο εγγραφών: 470
# Σελίδα 4 | Τρέχον σύνολο εγγραφών: 570
# Σελίδα 5 | Τρέχον σύνολο εγγραφών: 670
# Σελίδα 6 | Τρέχον σύνολο εγγραφών: 770
# Σελίδα 7 | Τρέχον σύνολο εγγραφών: 870
# Σελίδα 8 | Τρέχον σύνολο εγγραφών: 970
# Σελίδα 9 | Τρέχον σύνολο εγγραφών: 1070
# Σελίδα 10 | Τρέχον σύνολο εγγραφών: 1170
# Σελίδα 11 | Τρέχον σύνολο εγγραφών: 1270
# Σελίδα 12 | Τρέχον σύνολο εγγραφών: 1370
# Σελίδα 13 | Τρέχον σύνολο εγγραφών: 1470
# Σελίδα 14 | Τρέχον σύνολο εγγραφών: 1570
# Σελίδα 15 | Τρέχον σύνολο εγγραφών: 1670
# Σελίδα 16 | Τρέχον σύνολο εγγραφών: 1770
# Σελίδα 17 | Τρέχον σύνολο εγγραφών: 1870
# Σελίδα 18 | Τρέχον σύνολο εγγραφών: 1970
# Σελίδα 19 | Τρέχον σύνολο εγγραφών: 2070
# Σελίδα 20 | Τρέχον σύνολο εγγραφών: 2170
# Σελίδα 21 | Τρέχον σύνολο εγγραφών: 2270
# Σελίδα 22 | Τρέχον σύνολο εγγραφών: 2370
# Σελίδα 23 | Τρέχον σύνολο εγγραφών: 2470
# Σελίδα 24 | Τρέχον σύνολο εγγραφών: 2570
# Σελίδα 25 | Τρέχον σύνολο εγγραφών: 2670
# Σελίδα 26 | Τρέχον σύνολο εγγραφών: 2770
# Σελίδα 27 | Τρέχον σύνολο εγγραφών: 2870
# Σελίδα 28 | Τρέχον σύνολο εγγραφών: 2970
# Σελίδα 29 | Τρέχον σύνολο εγγραφών: 3070
# Σελίδα 30 | Τρέχον σύνολο εγγραφών: 3170
# Σελίδα 31 | Τρέχον σύνολο εγγραφών: 3270
# Σελίδα 32 | Τρέχον σύνολο εγγραφών: 3370
# Σελίδα 33 | Τρέχον σύνολο εγγραφών: 3449
# --- Συλλογή για: 'συντήρηση σχολείων' ---
# Σελίδα 0 | Τρέχον σύνολο εγγραφών: 3549
# Σελίδα 1 | Τρέχον σύνολο εγγραφών: 3649
# Σελίδα 2 | Τρέχον σύνολο εγγραφών: 3749
# Σελίδα 3 | Τρέχον σύνολο εγγραφών: 3849
# Σελίδα 4 | Τρέχον σύνολο εγγραφών: 3949
# Σελίδα 5 | Τρέχον σύνολο εγγραφών: 4049
# Σελίδα 6 | Τρέχον σύνολο εγγραφών: 4149
# Σελίδα 7 | Τρέχον σύνολο εγγραφών: 4249
# Σελίδα 8 | Τρέχον σύνολο εγγραφών: 4349
# Σελίδα 9 | Τρέχον σύνολο εγγραφών: 4449
# Σελίδα 10 | Τρέχον σύνολο εγγραφών: 4549
# Σελίδα 11 | Τρέχον σύνολο εγγραφών: 4649
# Σελίδα 12 | Τρέχον σύνολο εγγραφών: 4749
# Σελίδα 13 | Τρέχον σύνολο εγγραφών: 4849
# Σελίδα 14 | Τρέχον σύνολο εγγραφών: 4949
# Σελίδα 15 | Τρέχον σύνολο εγγραφών: 5049
# Σελίδα 16 | Τρέχον σύνολο εγγραφών: 5149
# Σελίδα 17 | Τρέχον σύνολο εγγραφών: 5249
# Σελίδα 18 | Τρέχον σύνολο εγγραφών: 5349
# Σελίδα 19 | Τρέχον σύνολο εγγραφών: 5449
# Σελίδα 20 | Τρέχον σύνολο εγγραφών: 5549
# Σελίδα 21 | Τρέχον σύνολο εγγραφών: 5649
# Σελίδα 22 | Τρέχον σύνολο εγγραφών: 5749
# Σελίδα 23 | Τρέχον σύνολο εγγραφών: 5849
# Σελίδα 24 | Τρέχον σύνολο εγγραφών: 5949
# Σελίδα 25 | Τρέχον σύνολο εγγραφών: 6049
# Σελίδα 26 | Τρέχον σύνολο εγγραφών: 6149
# Σελίδα 27 | Τρέχον σύνολο εγγραφών: 6249
# Σελίδα 28 | Τρέχον σύνολο εγγραφών: 6349
# Σελίδα 29 | Τρέχον σύνολο εγγραφών: 6449
# Σελίδα 30 | Τρέχον σύνολο εγγραφών: 6549
# Σελίδα 31 | Τρέχον σύνολο εγγραφών: 6649
# Σελίδα 32 | Τρέχον σύνολο εγγραφών: 6749
# Σελίδα 33 | Τρέχον σύνολο εγγραφών: 6828
# --- Συλλογή για: 'συντήρηση σχολικών' ---
# Σελίδα 0 | Τρέχον σύνολο εγγραφών: 6928
# Σελίδα 1 | Τρέχον σύνολο εγγραφών: 7028
# Σελίδα 2 | Τρέχον σύνολο εγγραφών: 7128
# Σελίδα 3 | Τρέχον σύνολο εγγραφών: 7228
# Σελίδα 4 | Τρέχον σύνολο εγγραφών: 7328
# Σελίδα 5 | Τρέχον σύνολο εγγραφών: 7428
# Σελίδα 6 | Τρέχον σύνολο εγγραφών: 7528
# Σελίδα 7 | Τρέχον σύνολο εγγραφών: 7628
# Σελίδα 8 | Τρέχον σύνολο εγγραφών: 7728
# Σελίδα 9 | Τρέχον σύνολο εγγραφών: 7828
# Σελίδα 10 | Τρέχον σύνολο εγγραφών: 7928
# Σελίδα 11 | Τρέχον σύνολο εγγραφών: 8028
# Σελίδα 12 | Τρέχον σύνολο εγγραφών: 8128
# Σελίδα 13 | Τρέχον σύνολο εγγραφών: 8228
# Σελίδα 14 | Τρέχον σύνολο εγγραφών: 8328
# Σελίδα 15 | Τρέχον σύνολο εγγραφών: 8428
# Σελίδα 16 | Τρέχον σύνολο εγγραφών: 8528
# Σελίδα 17 | Τρέχον σύνολο εγγραφών: 8628
# Σελίδα 18 | Τρέχον σύνολο εγγραφών: 8728
# Σελίδα 19 | Τρέχον σύνολο εγγραφών: 8828
# Σελίδα 20 | Τρέχον σύνολο εγγραφών: 8928
# Σελίδα 21 | Τρέχον σύνολο εγγραφών: 9028
# Σελίδα 22 | Τρέχον σύνολο εγγραφών: 9128
# Σελίδα 23 | Τρέχον σύνολο εγγραφών: 9228
# Σελίδα 24 | Τρέχον σύνολο εγγραφών: 9328
# Σελίδα 25 | Τρέχον σύνολο εγγραφών: 9428
# Σελίδα 26 | Τρέχον σύνολο εγγραφών: 9528
# Σελίδα 27 | Τρέχον σύνολο εγγραφών: 9628
# Σελίδα 28 | Τρέχον σύνολο εγγραφών: 9728
# Σελίδα 29 | Τρέχον σύνολο εγγραφών: 9828
# Σελίδα 30 | Τρέχον σύνολο εγγραφών: 9928
# Σελίδα 31 | Τρέχον σύνολο εγγραφών: 10028
# Σελίδα 32 | Τρέχον σύνολο εγγραφών: 10128
# Σελίδα 33 | Τρέχον σύνολο εγγραφών: 10228
# Σελίδα 34 | Τρέχον σύνολο εγγραφών: 10328
# Σελίδα 35 | Τρέχον σύνολο εγγραφών: 10428
# Σελίδα 36 | Τρέχον σύνολο εγγραφών: 10528
# Σελίδα 37 | Τρέχον σύνολο εγγραφών: 10628
# Σελίδα 38 | Τρέχον σύνολο εγγραφών: 10728
# Σελίδα 39 | Τρέχον σύνολο εγγραφών: 10828
# Σελίδα 40 | Τρέχον σύνολο εγγραφών: 10928
# Σελίδα 41 | Τρέχον σύνολο εγγραφών: 11028
# Σελίδα 42 | Τρέχον σύνολο εγγραφών: 11128
# Σελίδα 43 | Τρέχον σύνολο εγγραφών: 11228
# Σελίδα 44 | Τρέχον σύνολο εγγραφών: 11328
# Σελίδα 45 | Τρέχον σύνολο εγγραφών: 11428
# Σελίδα 46 | Τρέχον σύνολο εγγραφών: 11528
# Σελίδα 47 | Τρέχον σύνολο εγγραφών: 11628
# Σελίδα 48 | Τρέχον σύνολο εγγραφών: 11728
# Σελίδα 49 | Τρέχον σύνολο εγγραφών: 11828
# Σελίδα 50 | Τρέχον σύνολο εγγραφών: 11928
# Σελίδα 51 | Τρέχον σύνολο εγγραφών: 12028
# Σελίδα 52 | Τρέχον σύνολο εγγραφών: 12128
# Σελίδα 53 | Τρέχον σύνολο εγγραφών: 12228
# Σελίδα 54 | Τρέχον σύνολο εγγραφών: 12328
# Σελίδα 55 | Τρέχον σύνολο εγγραφών: 12428
# Σελίδα 56 | Τρέχον σύνολο εγγραφών: 12528
# Σελίδα 57 | Τρέχον σύνολο εγγραφών: 12628
# Σελίδα 58 | Τρέχον σύνολο εγγραφών: 12728
# Σελίδα 59 | Τρέχον σύνολο εγγραφών: 12828
# Σελίδα 60 | Τρέχον σύνολο εγγραφών: 12928
# Σελίδα 61 | Τρέχον σύνολο εγγραφών: 13028
# Σελίδα 62 | Τρέχον σύνολο εγγραφών: 13128
# Σελίδα 63 | Τρέχον σύνολο εγγραφών: 13228
# Σελίδα 64 | Τρέχον σύνολο εγγραφών: 13328
# Σελίδα 65 | Τρέχον σύνολο εγγραφών: 13428
# Σελίδα 66 | Τρέχον σύνολο εγγραφών: 13528
# Σελίδα 67 | Τρέχον σύνολο εγγραφών: 13628
# Σελίδα 68 | Τρέχον σύνολο εγγραφών: 13728
# Σελίδα 69 | Τρέχον σύνολο εγγραφών: 13828
# Σελίδα 70 | Τρέχον σύνολο εγγραφών: 13928
# Σελίδα 71 | Τρέχον σύνολο εγγραφών: 14028
# Σελίδα 72 | Τρέχον σύνολο εγγραφών: 14128
# Σελίδα 73 | Τρέχον σύνολο εγγραφών: 14228
# Σελίδα 74 | Τρέχον σύνολο εγγραφών: 14328
# Σελίδα 75 | Τρέχον σύνολο εγγραφών: 14428
# Σελίδα 76 | Τρέχον σύνολο εγγραφών: 14528
# Σελίδα 77 | Τρέχον σύνολο εγγραφών: 14628
# Σελίδα 78 | Τρέχον σύνολο εγγραφών: 14728
# Σελίδα 79 | Τρέχον σύνολο εγγραφών: 14828
# Σελίδα 80 | Τρέχον σύνολο εγγραφών: 14928
# Σελίδα 81 | Τρέχον σύνολο εγγραφών: 15028
# Σελίδα 82 | Τρέχον σύνολο εγγραφών: 15128
# Σελίδα 83 | Τρέχον σύνολο εγγραφών: 15228
# Σελίδα 84 | Τρέχον σύνολο εγγραφών: 15328
# Σελίδα 85 | Τρέχον σύνολο εγγραφών: 15428
# Σελίδα 86 | Τρέχον σύνολο εγγραφών: 15528
# Σελίδα 87 | Τρέχον σύνολο εγγραφών: 15628
# Σελίδα 88 | Τρέχον σύνολο εγγραφών: 15728
# Σελίδα 89 | Τρέχον σύνολο εγγραφών: 15828
# Σελίδα 90 | Τρέχον σύνολο εγγραφών: 15928
# Σελίδα 91 | Τρέχον σύνολο εγγραφών: 16028
# Σελίδα 92 | Τρέχον σύνολο εγγραφών: 16128
# Σελίδα 93 | Τρέχον σύνολο εγγραφών: 16228
# Σελίδα 94 | Τρέχον σύνολο εγγραφών: 16328
# Σελίδα 95 | Τρέχον σύνολο εγγραφών: 16428
# Σελίδα 96 | Τρέχον σύνολο εγγραφών: 16528
# Σελίδα 97 | Τρέχον σύνολο εγγραφών: 16628
# Σελίδα 98 | Τρέχον σύνολο εγγραφών: 16728
# Σελίδα 99 | Τρέχον σύνολο εγγραφών: 16828
# Σελίδα 100 | Τρέχον σύνολο εγγραφών: 16928
# Σελίδα 101 | Τρέχον σύνολο εγγραφών: 17028
# Σελίδα 102 | Τρέχον σύνολο εγγραφών: 17128
# Σελίδα 103 | Τρέχον σύνολο εγγραφών: 17228
# Σελίδα 104 | Τρέχον σύνολο εγγραφών: 17328
# Σελίδα 105 | Τρέχον σύνολο εγγραφών: 17428
# Σελίδα 106 | Τρέχον σύνολο εγγραφών: 17528
# Σελίδα 107 | Τρέχον σύνολο εγγραφών: 17628
# Σελίδα 108 | Τρέχον σύνολο εγγραφών: 17728
# Σελίδα 109 | Τρέχον σύνολο εγγραφών: 17828
# Σελίδα 110 | Τρέχον σύνολο εγγραφών: 17928
# Σελίδα 111 | Τρέχον σύνολο εγγραφών: 18028
# Σελίδα 112 | Τρέχον σύνολο εγγραφών: 18128
# Σελίδα 113 | Τρέχον σύνολο εγγραφών: 18228
# Σελίδα 114 | Τρέχον σύνολο εγγραφών: 18328
# Σελίδα 115 | Τρέχον σύνολο εγγραφών: 18428
# Σελίδα 116 | Τρέχον σύνολο εγγραφών: 18528
# Σελίδα 117 | Τρέχον σύνολο εγγραφών: 18628
# Σελίδα 118 | Τρέχον σύνολο εγγραφών: 18728
# Σελίδα 119 | Τρέχον σύνολο εγγραφών: 18828
# Σελίδα 120 | Τρέχον σύνολο εγγραφών: 18928
# Σελίδα 121 | Τρέχον σύνολο εγγραφών: 19028
# Σελίδα 122 | Τρέχον σύνολο εγγραφών: 19128
# Σελίδα 123 | Τρέχον σύνολο εγγραφών: 19228
# Σελίδα 124 | Τρέχον σύνολο εγγραφών: 19328
# Σελίδα 125 | Τρέχον σύνολο εγγραφών: 19428
# Σελίδα 126 | Τρέχον σύνολο εγγραφών: 19528
# Σελίδα 127 | Τρέχον σύνολο εγγραφών: 19628
# Σελίδα 128 | Τρέχον σύνολο εγγραφών: 19728
# Σελίδα 129 | Τρέχον σύνολο εγγραφών: 19828
# Σελίδα 130 | Τρέχον σύνολο εγγραφών: 19928
# Σελίδα 131 | Τρέχον σύνολο εγγραφών: 20028
# Σελίδα 132 | Τρέχον σύνολο εγγραφών: 20128
# Σελίδα 133 | Τρέχον σύνολο εγγραφών: 20228
# Σελίδα 134 | Τρέχον σύνολο εγγραφών: 20328
# Σελίδα 135 | Τρέχον σύνολο εγγραφών: 20428
# Σελίδα 136 | Τρέχον σύνολο εγγραφών: 20528
# Σελίδα 137 | Τρέχον σύνολο εγγραφών: 20628
# Σελίδα 138 | Τρέχον σύνολο εγγραφών: 20728
# Σελίδα 139 | Τρέχον σύνολο εγγραφών: 20828
# Σελίδα 140 | Τρέχον σύνολο εγγραφών: 20928
# Σελίδα 141 | Τρέχον σύνολο εγγραφών: 21028
# Σελίδα 142 | Τρέχον σύνολο εγγραφών: 21128
# Σελίδα 143 | Τρέχον σύνολο εγγραφών: 21228
# Σελίδα 144 | Τρέχον σύνολο εγγραφών: 21328
# Σελίδα 145 | Τρέχον σύνολο εγγραφών: 21428
# Σελίδα 146 | Τρέχον σύνολο εγγραφών: 21528
# Σελίδα 147 | Τρέχον σύνολο εγγραφών: 21628
# Σελίδα 148 | Τρέχον σύνολο εγγραφών: 21728
# Σελίδα 149 | Τρέχον σύνολο εγγραφών: 21828
# Σελίδα 150 | Τρέχον σύνολο εγγραφών: 21928
# Σελίδα 151 | Τρέχον σύνολο εγγραφών: 22028
# Σελίδα 152 | Τρέχον σύνολο εγγραφών: 22128
# Σελίδα 153 | Τρέχον σύνολο εγγραφών: 22228
# Σελίδα 154 | Τρέχον σύνολο εγγραφών: 22328
# Σελίδα 155 | Τρέχον σύνολο εγγραφών: 22428
# Σελίδα 156 | Τρέχον σύνολο εγγραφών: 22528
# Σελίδα 157 | Τρέχον σύνολο εγγραφών: 22628
# Σελίδα 158 | Τρέχον σύνολο εγγραφών: 22728
# Σελίδα 159 | Τρέχον σύνολο εγγραφών: 22828
# Σελίδα 160 | Τρέχον σύνολο εγγραφών: 22928
# Σελίδα 161 | Τρέχον σύνολο εγγραφών: 23028
# Σελίδα 162 | Τρέχον σύνολο εγγραφών: 23128
# Σελίδα 163 | Τρέχον σύνολο εγγραφών: 23228
# Σελίδα 164 | Τρέχον σύνολο εγγραφών: 23328
# Σελίδα 165 | Τρέχον σύνολο εγγραφών: 23428
# Σελίδα 166 | Τρέχον σύνολο εγγραφών: 23528
# Σελίδα 167 | Τρέχον σύνολο εγγραφών: 23628
# Σελίδα 168 | Τρέχον σύνολο εγγραφών: 23728
# Σελίδα 169 | Τρέχον σύνολο εγγραφών: 23828
# Σελίδα 170 | Τρέχον σύνολο εγγραφών: 23928
# Σελίδα 171 | Τρέχον σύνολο εγγραφών: 24028
# Σελίδα 172 | Τρέχον σύνολο εγγραφών: 24128
# Σελίδα 173 | Τρέχον σύνολο εγγραφών: 24228
# Σελίδα 174 | Τρέχον σύνολο εγγραφών: 24328
# Σελίδα 175 | Τρέχον σύνολο εγγραφών: 24428
# Σελίδα 176 | Τρέχον σύνολο εγγραφών: 24528
# Σελίδα 177 | Τρέχον σύνολο εγγραφών: 24628
# Σελίδα 178 | Τρέχον σύνολο εγγραφών: 24728
# Σελίδα 179 | Τρέχον σύνολο εγγραφών: 24828
# Σελίδα 180 | Τρέχον σύνολο εγγραφών: 24928
# Σελίδα 181 | Τρέχον σύνολο εγγραφών: 25028
# Σελίδα 182 | Τρέχον σύνολο εγγραφών: 25128
# Σελίδα 183 | Τρέχον σύνολο εγγραφών: 25228
# Σελίδα 184 | Τρέχον σύνολο εγγραφών: 25328
# Σελίδα 185 | Τρέχον σύνολο εγγραφών: 25428
# Σελίδα 186 | Τρέχον σύνολο εγγραφών: 25528
# Σελίδα 187 | Τρέχον σύνολο εγγραφών: 25628
# Σελίδα 188 | Τρέχον σύνολο εγγραφών: 25728
# Σελίδα 189 | Τρέχον σύνολο εγγραφών: 25828
# Σελίδα 190 | Τρέχον σύνολο εγγραφών: 25928
# Σελίδα 191 | Τρέχον σύνολο εγγραφών: 26028
# Σελίδα 192 | Τρέχον σύνολο εγγραφών: 26128
# Σελίδα 193 | Τρέχον σύνολο εγγραφών: 26228
# Σελίδα 194 | Τρέχον σύνολο εγγραφών: 26328
# Σελίδα 195 | Τρέχον σύνολο εγγραφών: 26428
# Σελίδα 196 | Τρέχον σύνολο εγγραφών: 26528
# Σελίδα 197 | Τρέχον σύνολο εγγραφών: 26628
# Σελίδα 198 | Τρέχον σύνολο εγγραφών: 26728
# Σελίδα 199 | Τρέχον σύνολο εγγραφών: 26828
# Σελίδα 200 | Τρέχον σύνολο εγγραφών: 26928
# Σελίδα 201 | Τρέχον σύνολο εγγραφών: 27028
# Σελίδα 202 | Τρέχον σύνολο εγγραφών: 27128
# Σελίδα 203 | Τρέχον σύνολο εγγραφών: 27228
# Σελίδα 204 | Τρέχον σύνολο εγγραφών: 27328
# Σελίδα 205 | Τρέχον σύνολο εγγραφών: 27428
# Σελίδα 206 | Τρέχον σύνολο εγγραφών: 27528
# Σελίδα 207 | Τρέχον σύνολο εγγραφών: 27628
# Σελίδα 208 | Τρέχον σύνολο εγγραφών: 27728
# Σελίδα 209 | Τρέχον σύνολο εγγραφών: 27828
# Σελίδα 210 | Τρέχον σύνολο εγγραφών: 27928
# Σελίδα 211 | Τρέχον σύνολο εγγραφών: 28028
# Σελίδα 212 | Τρέχον σύνολο εγγραφών: 28128
# Σελίδα 213 | Τρέχον σύνολο εγγραφών: 28228
# Σελίδα 214 | Τρέχον σύνολο εγγραφών: 28328
# Σελίδα 215 | Τρέχον σύνολο εγγραφών: 28428
# Σελίδα 216 | Τρέχον σύνολο εγγραφών: 28528
# Σελίδα 217 | Τρέχον σύνολο εγγραφών: 28628
# Σελίδα 218 | Τρέχον σύνολο εγγραφών: 28728
# Σελίδα 219 | Τρέχον σύνολο εγγραφών: 28828
# Σελίδα 220 | Τρέχον σύνολο εγγραφών: 28928
# Σελίδα 221 | Τρέχον σύνολο εγγραφών: 29028
# Σελίδα 222 | Τρέχον σύνολο εγγραφών: 29128
# Σελίδα 223 | Τρέχον σύνολο εγγραφών: 29228
# Σελίδα 224 | Τρέχον σύνολο εγγραφών: 29328
# Σελίδα 225 | Τρέχον σύνολο εγγραφών: 29428
# Σελίδα 226 | Τρέχον σύνολο εγγραφών: 29528
# Σελίδα 227 | Τρέχον σύνολο εγγραφών: 29628
# Σελίδα 228 | Τρέχον σύνολο εγγραφών: 29728
# Σελίδα 229 | Τρέχον σύνολο εγγραφών: 29828
# Σελίδα 230 | Τρέχον σύνολο εγγραφών: 29928
# Σελίδα 231 | Τρέχον σύνολο εγγραφών: 30028
# Σελίδα 232 | Τρέχον σύνολο εγγραφών: 30128
# Σελίδα 233 | Τρέχον σύνολο εγγραφών: 30228
# Σελίδα 234 | Τρέχον σύνολο εγγραφών: 30328
# Σελίδα 235 | Τρέχον σύνολο εγγραφών: 30428
# Σελίδα 236 | Τρέχον σύνολο εγγραφών: 30528
# Σελίδα 237 | Τρέχον σύνολο εγγραφών: 30628
# Σελίδα 238 | Τρέχον σύνολο εγγραφών: 30728
# Σελίδα 239 | Τρέχον σύνολο εγγραφών: 30828
# Σελίδα 240 | Τρέχον σύνολο εγγραφών: 30928
# Σελίδα 241 | Τρέχον σύνολο εγγραφών: 31028
# Σελίδα 242 | Τρέχον σύνολο εγγραφών: 31128
# Σελίδα 243 | Τρέχον σύνολο εγγραφών: 31228
# Σελίδα 244 | Τρέχον σύνολο εγγραφών: 31328
# Σελίδα 245 | Τρέχον σύνολο εγγραφών: 31428
# Σελίδα 246 | Τρέχον σύνολο εγγραφών: 31528
# Σελίδα 247 | Τρέχον σύνολο εγγραφών: 31628
# Σελίδα 248 | Τρέχον σύνολο εγγραφών: 31728
# Σελίδα 249 | Τρέχον σύνολο εγγραφών: 31828
# Σελίδα 250 | Τρέχον σύνολο εγγραφών: 31928
# Σελίδα 251 | Τρέχον σύνολο εγγραφών: 32028
# Σελίδα 252 | Τρέχον σύνολο εγγραφών: 32128
# Σελίδα 253 | Τρέχον σύνολο εγγραφών: 32228
# Σελίδα 254 | Τρέχον σύνολο εγγραφών: 32328
# Σελίδα 255 | Τρέχον σύνολο εγγραφών: 32428
# Σελίδα 256 | Τρέχον σύνολο εγγραφών: 32528
# Σελίδα 257 | Τρέχον σύνολο εγγραφών: 32628
# Σελίδα 258 | Τρέχον σύνολο εγγραφών: 32728
# Σελίδα 259 | Τρέχον σύνολο εγγραφών: 32828
# Σελίδα 260 | Τρέχον σύνολο εγγραφών: 32928
# Σελίδα 261 | Τρέχον σύνολο εγγραφών: 33028
# Σελίδα 262 | Τρέχον σύνολο εγγραφών: 33128
# Σελίδα 263 | Τρέχον σύνολο εγγραφών: 33228
# Σελίδα 264 | Τρέχον σύνολο εγγραφών: 33328
# Σελίδα 265 | Τρέχον σύνολο εγγραφών: 33428
# Σελίδα 266 | Τρέχον σύνολο εγγραφών: 33528
# Σελίδα 267 | Τρέχον σύνολο εγγραφών: 33628
# Σελίδα 268 | Τρέχον σύνολο εγγραφών: 33728
# Σελίδα 269 | Τρέχον σύνολο εγγραφών: 33828
# Σελίδα 270 | Τρέχον σύνολο εγγραφών: 33928
# Σελίδα 271 | Τρέχον σύνολο εγγραφών: 34028
# Σελίδα 272 | Τρέχον σύνολο εγγραφών: 34128
# Σελίδα 273 | Τρέχον σύνολο εγγραφών: 34228
# Σελίδα 274 | Τρέχον σύνολο εγγραφών: 34328
# Σελίδα 275 | Τρέχον σύνολο εγγραφών: 34428
# Σελίδα 276 | Τρέχον σύνολο εγγραφών: 34528
# Σελίδα 277 | Τρέχον σύνολο εγγραφών: 34628
# Σελίδα 278 | Τρέχον σύνολο εγγραφών: 34728
# Σελίδα 279 | Τρέχον σύνολο εγγραφών: 34828
# Σελίδα 280 | Τρέχον σύνολο εγγραφών: 34928
# Σελίδα 281 | Τρέχον σύνολο εγγραφών: 35028
# Σελίδα 282 | Τρέχον σύνολο εγγραφών: 35128
# Σελίδα 283 | Τρέχον σύνολο εγγραφών: 35228
# Σελίδα 284 | Τρέχον σύνολο εγγραφών: 35328
# Σελίδα 285 | Τρέχον σύνολο εγγραφών: 35428
# Σελίδα 286 | Τρέχον σύνολο εγγραφών: 35528
# Σελίδα 287 | Τρέχον σύνολο εγγραφών: 35628
# Σελίδα 288 | Τρέχον σύνολο εγγραφών: 35728
# Σελίδα 289 | Τρέχον σύνολο εγγραφών: 35828
# Σελίδα 290 | Τρέχον σύνολο εγγραφών: 35928
# Σελίδα 291 | Τρέχον σύνολο εγγραφών: 36028
# Σελίδα 292 | Τρέχον σύνολο εγγραφών: 36128
# Σελίδα 293 | Τρέχον σύνολο εγγραφών: 36228
# Σελίδα 294 | Τρέχον σύνολο εγγραφών: 36328
# Σελίδα 295 | Τρέχον σύνολο εγγραφών: 36428
# Σελίδα 296 | Τρέχον σύνολο εγγραφών: 36528
# Σελίδα 297 | Τρέχον σύνολο εγγραφών: 36628
# Σελίδα 298 | Τρέχον σύνολο εγγραφών: 36728
# Σελίδα 299 | Τρέχον σύνολο εγγραφών: 36828
# Σελίδα 300 | Τρέχον σύνολο εγγραφών: 36928
# Σελίδα 301 | Τρέχον σύνολο εγγραφών: 37028
# Σελίδα 302 | Τρέχον σύνολο εγγραφών: 37128
# Σελίδα 303 | Τρέχον σύνολο εγγραφών: 37228
# Σελίδα 304 | Τρέχον σύνολο εγγραφών: 37328
# Σελίδα 305 | Τρέχον σύνολο εγγραφών: 37428
# Σελίδα 306 | Τρέχον σύνολο εγγραφών: 37528
# Σελίδα 307 | Τρέχον σύνολο εγγραφών: 37628
# Σελίδα 308 | Τρέχον σύνολο εγγραφών: 37728
# Σελίδα 309 | Τρέχον σύνολο εγγραφών: 37735
# --- Συλλογή για: 'επισκευή σχολείου' ---
# Σελίδα 0 | Τρέχον σύνολο εγγραφών: 37835
# Σελίδα 1 | Τρέχον σύνολο εγγραφών: 37935
# Σελίδα 2 | Τρέχον σύνολο εγγραφών: 38035
# Σελίδα 3 | Τρέχον σύνολο εγγραφών: 38135
# Σελίδα 4 | Τρέχον σύνολο εγγραφών: 38235
# Σελίδα 5 | Τρέχον σύνολο εγγραφών: 38335
# Σελίδα 6 | Τρέχον σύνολο εγγραφών: 38435
# Σελίδα 7 | Τρέχον σύνολο εγγραφών: 38535
# Σελίδα 8 | Τρέχον σύνολο εγγραφών: 38635
# Σελίδα 9 | Τρέχον σύνολο εγγραφών: 38735
# Σελίδα 10 | Τρέχον σύνολο εγγραφών: 38810
# --- Συλλογή για: 'επισκευή σχολείων' ---
# Σελίδα 0 | Τρέχον σύνολο εγγραφών: 38910
# Σελίδα 1 | Τρέχον σύνολο εγγραφών: 39010
# Σελίδα 2 | Τρέχον σύνολο εγγραφών: 39110
# Σελίδα 3 | Τρέχον σύνολο εγγραφών: 39210
# Σελίδα 4 | Τρέχον σύνολο εγγραφών: 39310
# Σελίδα 5 | Τρέχον σύνολο εγγραφών: 39410
# Σελίδα 6 | Τρέχον σύνολο εγγραφών: 39510
# Σελίδα 7 | Τρέχον σύνολο εγγραφών: 39610
# Σελίδα 8 | Τρέχον σύνολο εγγραφών: 39710
# Σελίδα 9 | Τρέχον σύνολο εγγραφών: 39810
# Σελίδα 10 | Τρέχον σύνολο εγγραφών: 39885
# --- Συλλογή για: 'ενεργειακή αναβάθμιση σχολ' ---
# Σελίδα 0 | Τρέχον σύνολο εγγραφών: 39985
# Σελίδα 1 | Τρέχον σύνολο εγγραφών: 40085
# Σελίδα 2 | Τρέχον σύνολο εγγραφών: 40185
# Σελίδα 3 | Τρέχον σύνολο εγγραφών: 40285
# Σελίδα 4 | Τρέχον σύνολο εγγραφών: 40385
# Σελίδα 5 | Τρέχον σύνολο εγγραφών: 40485
# Σελίδα 6 | Τρέχον σύνολο εγγραφών: 40585
# Σελίδα 7 | Τρέχον σύνολο εγγραφών: 40685
# Σελίδα 8 | Τρέχον σύνολο εγγραφών: 40785
# Σελίδα 9 | Τρέχον σύνολο εγγραφών: 40885
# Σελίδα 10 | Τρέχον σύνολο εγγραφών: 40985
# Σελίδα 11 | Τρέχον σύνολο εγγραφών: 41085
# Σελίδα 12 | Τρέχον σύνολο εγγραφών: 41185
# Σελίδα 13 | Τρέχον σύνολο εγγραφών: 41285
# Σελίδα 14 | Τρέχον σύνολο εγγραφών: 41385
# Σελίδα 15 | Τρέχον σύνολο εγγραφών: 41485
# Σελίδα 16 | Τρέχον σύνολο εγγραφών: 41585
# Σελίδα 17 | Τρέχον σύνολο εγγραφών: 41685
# Σελίδα 18 | Τρέχον σύνολο εγγραφών: 41718
#
# Τέλος συλλογής! Μαζεύτηκαν συνολικά 41718 εγγραφές (μαζί με διπλότυπα).

# %%
import pandas as pd

# 1. Μετατροπή της φρέσκιας λίστας σε DataFrame
df_raw = pd.DataFrame(all_decisions)
print(f"Αρχικές εγγραφές στη λίστα: {len(df_raw)}")

# 2. Εξαγωγή του καθαρού ονόματος του Δήμου
df_raw['foreas_name'] = df_raw['organization'].apply(
    lambda x: x.get('label', 'Άγνωστος Φορέας') if isinstance(x, dict) else 'Χωρίς Φορέα'
)

# 3. Αφαίρεση διπλοτύπων με βάση τον μοναδικό ΑΔΑ (Deduplication)
df_unique = df_raw.drop_duplicates(subset=['ada']).copy()
print(f"Μοναδικές εγγραφές μετά την αφαίρεση διπλοτύπων: {len(df_unique)}")
# Out:
# Αρχικές εγγραφές στη λίστα: 41718
# Μοναδικές εγγραφές μετά την αφαίρεση διπλοτύπων: 37193

# %%
# Δείξε μας τι είδους αποφάσεις έχουμε μέσα στο dataset
print(df_unique['decisionType'].value_counts().head(10))
# Out:
# decisionType
# {'uid': 'Β.2.2', 'label': 'ΟΡΙΣΤΙΚΟΠΟΙΗΣΗ ΠΛΗΡΩΜΗΣ'}                                                                                  8273
# {'uid': 'Β.1.3', 'label': 'ΑΝΑΛΗΨΗ ΥΠΟΧΡΕΩΣΗΣ'}                                                                                       7238
# {'uid': 'Α.2', 'label': 'ΚΑΝΟΝΙΣΤΙΚΗ ΠΡΑΞΗ'}                                                                                          6441
# {'uid': '2.4.7.1', 'label': 'ΛΟΙΠΕΣ ΑΤΟΜΙΚΕΣ ΔΙΟΙΚΗΤΙΚΕΣ ΠΡΑΞΕΙΣ'}                                                                    6089
# {'uid': 'Δ.1', 'label': 'ΑΝΑΘΕΣΗ ΕΡΓΩΝ / ΠΡΟΜΗΘΕΙΩΝ / ΥΠΗΡΕΣΙΩΝ / ΜΕΛΕΤΩΝ'}                                                           3323
# {'uid': 'Β.1.1', 'label': 'ΕΓΚΡΙΣΗ ΠΡΟΥΠΟΛΟΓΙΣΜΟΥ'}                                                                                   1493
# {'uid': 'Β.2.1', 'label': 'ΕΓΚΡΙΣΗ ΔΑΠΑΝΗΣ'}                                                                                          1026
# {'uid': 'Δ.2.1', 'label': 'ΠΕΡΙΛΗΨΗ ΔΙΑΚΗΡΥΞΗΣ'}                                                                                       883
# {'uid': 'Γ.2', 'label': 'ΠΡΑΞΗ ΠΟΥ ΑΦΟΡΑ ΣΕ ΣΥΛΛΟΓΙΚΟ ΟΡΓΑΝΟ - ΕΠΙΤΡΟΠΗ - ΟΜΑΔΑ ΕΡΓΑΣΙΑΣ - ΟΜΑΔΑ ΕΡΓΟΥ - ΜΕΛΗ ΣΥΛΛΟΓΙΚΟΥ ΟΡΓΑΝΟΥ'}     651
# {'uid': 'Δ.2.2', 'label': 'ΚΑΤΑΚΥΡΩΣΗ'}                                                                                                570
# Name: count, dtype: int64

# %%
# Συναρτησούλα που μπαίνει μέσα στο dictionary και παίρνει το 'label'
def get_decision_label(x):
    if isinstance(x, dict):
        return x.get('label', '')
    return str(x)

# Φιλτράρουμε κρατώντας ΜΟΝΟ την Οριστικοποίηση Πληρωμής
df_payments = df_unique[df_unique['decisionType'].apply(get_decision_label) == 'ΟΡΙΣΤΙΚΟΠΟΙΗΣΗ ΠΛΗΡΩΜΗΣ'].copy()
print(f"Πραγματικές πληρωμές (Οριστικοποιήσεις Πληρωμής) προς επεξεργασία: {len(df_payments)}")

# Αποθήκευση αυτής της λίστας metadata σε CSV για ασφάλεια
df_payments.to_csv('payments_metadata_only.csv', index=False, encoding='utf-8-sig')
print("Το αρχείο 'payments_metadata_only.csv' αποθηκεύτηκε επιτυχώς!")
# Out:
# Πραγματικές πληρωμές (Οριστικοποιήσεις Πληρωμής) προς επεξεργασία: 8273
# Το αρχείο 'payments_metadata_only.csv' αποθηκεύτηκε επιτυχώς!

# %%
import pandas as pd
df_payments = pd.read_csv('payments_metadata_only.csv')
print(f"Φορτώθηκαν {len(df_payments)} πληρωμές από το αρχείο.")
# Out:
# Φορτώθηκαν 8273 πληρωμές από το αρχείο.

# %%
# ============================================================
# ΤΕΛΙΚΗ, ΠΛΗΡΩΣ ΔΟΚΙΜΑΣΜΕΝΗ ΕΞΑΓΩΓΗ (rebuild v3 -- δοκιμασμενο σε 5 πραγματικα PDF)
#
# Νεες διορθωσεις σε σχεση με την προηγουμενη εκδοση:
#  1) Το "Ω" σε καποια PDF ειναι στην πραγματικοτητα το συμβολο OHM
#     (U+2126, απο τα ηλεκτρολογικα) και οχι το κανονικο ελληνικο Ω
#     (U+03A9) -- οπτικα ιδια, διαφορετικος χαρακτηρας. Διορθωνεται
#     οπως και το ∆ -> Δ.
#  2) Πολλα εντυπα γραφουν τις επικεφαλιδες με κενο αναμεσα σε κ ά θ ε
#     γραμμα (π.χ. "Σ Υ Ν Ο Λ Ο" αντι "ΣΥΝΟΛΟ"), κατι που εκανε αδυνατη
#     καθε αναζητηση λεξης-κλειδιου. Διορθωνεται με αφαιρεση κενων
#     αναμεσα σε μεμονωμενα γραμματα.
#  3) Πολυ μεγαλυτερη λιστα ετικετων για ποσο (ΠΛΗΡΩΤΕΟ, ΚΑΘΑΡΟ ΠΟΣΟ,
#     ΚΑΘΑΡ.ΔΙΚΑΙΟΥΧΟΥ, ΣΥΝΟΛΟ ΕΝΤΑΛΜΑΤΟΣ, ΣΥΝ.ΕΝΤ/ΤΟΣ κλπ) με προσοχη
#     να ΜΗΝ μπερδευεται το "ΣΥΝΟΛΟ ΚΡΑΤΗΣΕΩΝ" (κρατησεις, οχι ποσο) και
#     η "ΚΑΘΑΡΗ ΑΞΙΑ" (αξια προ ΦΠΑ -- διαφορετικη εννοια απο καθαρο
#     ποσο μετα κρατησεων!).
#  4) Αναδοχος: 5 στρατηγικες -- (Α) αγκυρα σε ΑΦΜ-9 ψηφια στην ιδια
#     γραμμη, (Β) αναζητηση νομικης μορφης Ο.Ε./Α.Ε./Ε.Π.Ε./Ι.Κ.Ε. σε
#     ολο το εγγραφο (πιανει περιπτωσεις πολυ μακρια απο την ετικετα
#     ΔΙΚΑΙΟΥΧΟΣ), (Β2) μοτιβο "ΟΝΟΜΑ ΕΠΩΝΥΜΟ ΚΑ 30.6261.05" συχνο σε
#     παλια εντυπα, (Γ) παλιος πινακας με "|", (Δ) γειτονια ετικετας
#     ΔΙΚΑΙΟΥΧ με ευρυτερο παραθυρο. Σε καθε στρατηγια αποκλειουμε:
#     σκουπιδια/συμβολα, boilerplate φρασεις (ΕΛΛΗΝΙΚΗ ΔΗΜΟΚΡΑΤΙΑ,
#     ΝΟΜΟΣ, ΤΑΜΕΙΑΚΗ ΥΠΗΡΕΣΙΑ κλπ), περιπτωσεις που ο "αναδοχος" =
#     ο ιδιος ο φορεας, και περιπτωσεις που ταυτιζεται με το subject
#     (= επαναλαμβανομενη περιγραφη, οχι ονομα).
#
# Δοκιμασμενο σε 5 πραγματικα PDF διαφορετικων δημων/ετων/προτυπων: 5/5 σωστα.
# ============================================================
import requests
import io
import pypdf
import os
import time
import pandas as pd
import re

input_file = 'diavgeia_scraped_full_data.csv'
output_file = 'diavgeia_final_extracted_v3.csv'   # νεο αρχειο -- κρατα το v2/προηγουμενο για συγκριση

df_payments = pd.read_csv(input_file)
required_cols = {'ada', 'documentUrl'}
missing = required_cols - set(df_payments.columns)
if missing:
    raise ValueError(f"Λείπουν απαραίτητες στήλες απο το {input_file}: {missing}.")
print(f"Φορτώθηκαν {len(df_payments)} εγγραφές. Στήλες: {list(df_payments.columns)}")

GREEK_FIX = str.maketrans('ΆΈΉΊΪΌΎΫΏ∆\u2126', 'ΑΕΗΙΙΟΥΥΩΔΩ')
MONEY = r'(\d{1,3}(?:\.\d{3})*,\d{2})'

def normalize(text):
    txt = text.upper().translate(GREEK_FIX)
    txt = re.sub(r'[ \t]+', ' ', txt)
    # Διορθωση "διαστιχου": "Χ Ρ Η Μ Α" -> "ΧΡΗΜΑ"
    txt = re.sub(r'(?:[Α-ΩΪΫ] ){2,}[Α-ΩΪΫ]', lambda m: m.group(0).replace(' ', ''), txt)
    return txt

def find_amount_near_label(flat_txt, label_pattern, window=70, exclude_after=None):
    candidates = []
    for m in re.finditer(label_pattern, flat_txt):
        if exclude_after and re.match(exclude_after, flat_txt[m.end(): m.end() + 15]):
            continue
        after = list(re.finditer(MONEY, flat_txt[m.end(): m.end() + window]))
        if after:
            candidates.append(after[0].group(1)); continue
        before = list(re.finditer(MONEY, flat_txt[max(0, m.start() - window): m.start()]))
        if before:
            candidates.append(before[-1].group(1))
    return candidates

NET_LABELS = [r'ΠΛΗΡΩΤΕΟ\s*ΠΟΣΟ', r'ΚΑΘΑΡΟ\s*ΠΟΣΟ', r'ΚΑΘΑΡ\.\s*ΔΙΚΑΙΟΥΧΟΥ',
              r'ΚΑΘΑΡ\.\s*ΠΟΣΟ', r'ΠΛΗΡΩΤΕΟ(?!\s*ΑΠΟ)']
GROSS_LABELS = [r'ΣΥΝΟΛΙΚΟ\s*ΠΟΣΟ', r'ΣΥΝΟΛΙΚΗ\s*ΑΞΙΑ', r'ΣΥΝΟΛΟ\s*ΕΝΤΑΛΜΑΤΟΣ',
                r'ΣΥΝ\.?\s*ΕΝΤ[\./]?\s*ΤΟΣ', r'ΣΥΝΟΛΟ(?!\s*ΚΡΑΤΗΣ)']

def extract_amounts(flat_txt):
    net, gross = [], []
    for lab in NET_LABELS:
        net += find_amount_near_label(flat_txt, lab)
    for lab in GROSS_LABELS:
        excl = r'\s*ΚΡΑΤΗΣ' if lab.startswith('ΣΥΝΟΛΟ(') else None
        gross += find_amount_near_label(flat_txt, lab, exclude_after=excl)
    return (net[-1] if net else None), (gross[-1] if gross else None)

def extract_assignment_type(flat_txt):
    if "ΑΠΕΥΘΕΙΑΣ ΑΝΑΘΕΣ" in flat_txt: return "Απευθείας Ανάθεση"
    if "ΣΥΝΟΠΤΙΚ" in flat_txt: return "Συνοπτικός Διαγωνισμός"
    if "ΑΝΟΙΚΤ" in flat_txt or "ΑΝΟΙΧΤ" in flat_txt: return "Ανοικτός Διαγωνισμός"
    if "ΠΡΟΧΕΙΡ" in flat_txt: return "Πρόχειρος Διαγωνισμός"
    if "ΔΙΑΓΩΝΙΣΜ" in flat_txt: return "Διαγωνισμός"
    if "ΑΝΑΘΕΣΗΣ" in flat_txt or "ΑΝΑΘΕΣΗ" in flat_txt: return "Ανάθεση (μη προσδιορισμένος τύπος)"
    return "Απλή Πληρωμή / Τακτική"

LABEL_PREFIXES = [r'^ΕΠΩΝΥΜΙΑ\.*\s*:?\s*', r'^ΟΝΟΜ/ΜΟ\s*Η\s*ΕΠΩΝΥΜΙΑ\.*\s*:?\s*',
                   r'^ΟΝΟΜΑΤΕΠΩΝΥΜΟ\.*\s*:?\s*', r'^ΔΙΚΑΙΟΥΧ\w*\.*\s*:?\s*']
def strip_label_prefix(s):
    for pat in LABEL_PREFIXES:
        s = re.sub(pat, '', s)
    return s.strip(' .:')

def _alnum(s):
    return re.sub(r'[^Α-ΩΪΫA-Z0-9]', '', s)

def overlaps_subject(cand, subject_norm):
    if not subject_norm or len(cand) < 6:
        return False
    c, s = _alnum(cand), _alnum(subject_norm)
    if not c or not s:
        return False
    return c in s or s in c or (len(c) > 15 and c[:15] in s)

BOILERPLATE = ["ΔΙΚΑΙΟΥΧ", "ΠΡΟΙΣΤΑΜΕΝ", "ΠΡ/ΝΟΣ", "ΛΟΓΙΣΤΗΡ", "ΔΗΜΑΡΧΟΣ", "ΤΑΜΙΑΣ", "ΑΘΕΩΡΗΤΟ",
               "ΑΙΤΙΑ", "ΠΛΗΡΩΜ", "ΠΟΣΟ", "ΕΥΡΩ", "ΕΝΤΑΛΜΑ", "ΟΛΟΓΡΑΦ", "ΑΡΙΘΜΗΤ", "ΚΡΑΤΗΣ", "ΣΥΝΟΛ",
               "ΤΑΜΕΙΑΚΗ ΥΠΗΡΕΣΙΑ", "ΠΛΗΡΩΤΕΟ ΑΠΟ", "ΑΙΤΙΟΛΟΓ", "ΧΡΗΜΑΤΟΔΟΤΗΣ", "ΚΑΤΑΣΤΑΣΗ ΠΛΗΡΩ",
               "ΕΛΛΗΝΙΚΗ ΔΗΜΟΚΡΑΤΙΑ", "ΝΟΜΟΣ ", "ΠΕΡΙΦΕΡΕΙΑ ", "ΟΙΚΟΝ", "ΧΡΗΣΗ ΤΟΥ ΕΤΟΥΣ"]

def is_garbage(cand, subject_norm=''):
    if len(cand) < 4: return True
    letters = sum(1 for c in cand if c.isalpha())
    if letters / max(len(cand), 1) < 0.5: return True
    if sum(c.isdigit() for c in cand) > 2: return True
    if any(w in cand for w in BOILERPLATE): return True
    if overlaps_subject(cand, subject_norm): return True
    return False

LEGAL_SUFFIXES = [r'\bΟ\.?\s?Ε\.?(?:\s|$)', r'\bΑ\.?\s?Ε\.?(?:\s|$)', r'\bΕ\.?\s?Π\.?\s?Ε\.?(?:\s|$)',
                   r'\bΙ\.?\s?Κ\.?\s?Ε\.?(?:\s|$)', r'ΚΟΙΝΟΠΡΑΞΙΑ', r'ΜΟΝΟΠΡΟΣΩΠΗ']
NAME_PLUS_BUDGETCODE = re.compile(r'^([Α-Ω]+(?:\s[Α-Ω]+){0,3})\s*[\d.,]*\s*ΚΑ\s+\d')

def extract_contractor(flat_txt, lines, foreas_name, subject=''):
    foreas_up = (foreas_name or '').strip().upper()
    subj_norm = re.sub(r'\s+', ' ', normalize(subject or ''))

    m = re.search(r'Α\.?Φ\.?Μ\.?\s*:?\s*([Α-ΩΪΫA-Z0-9\.\-\s&]{4,80}?)\s*(\d{9})\b', flat_txt)
    if m:
        name = strip_label_prefix(m.group(1).strip(' .-'))
        if not is_garbage(name, subj_norm) and name.upper() != foreas_up:
            return name

    for line in lines:
        if any(re.search(suf, line) for suf in LEGAL_SUFFIXES):
            cand = strip_label_prefix(line)
            cand = re.split(r'\s{2,}|,\s*ΚΑ\s|\bΚΑ\s\d', cand)[0].strip()
            if not is_garbage(cand, subj_norm) and cand.upper() != foreas_up and len(cand) <= 80:
                return cand

    for line in lines:
        m2 = NAME_PLUS_BUDGETCODE.match(line)
        if m2:
            cand = m2.group(1).strip()
            if not is_garbage(cand, subj_norm) and cand.upper() != foreas_up:
                return cand

    for i, line in enumerate(lines):
        if 'ΔΙΚΑΙΟΥΧ' in line and '|' in line:
            for j in range(i + 1, min(i + 6, len(lines))):
                row = lines[j]
                if not row.strip('-| ') or '|' not in row:
                    continue
                cell = row.split('|')[1].strip() if row.startswith('|') else row.split('|')[0].strip()
                if cell and not is_garbage(cell, subj_norm) and cell.upper() != foreas_up:
                    return cell
            break

    for i, line in enumerate(lines):
        if 'ΔΙΚΑΙΟΥΧ' in line:
            for idx in range(max(0, i - 10), min(len(lines), i + 10)):
                cand = strip_label_prefix(lines[idx].strip())
                if is_garbage(cand, subj_norm) or cand.upper() == foreas_up:
                    continue
                return cand
    return "Δεν εντοπίστηκε"

def process_pdf_text(raw_text, foreas_name='', subject=''):
    txt = normalize(raw_text)
    flat = re.sub(r'\s+', ' ', txt)
    lines = [l.strip() for l in txt.split('\n') if l.strip()]
    net, gross = extract_amounts(flat)
    return {
        'amount_net': net,
        'amount_gross': gross,
        'assignment_type': extract_assignment_type(flat),
        'contractor_name': extract_contractor(flat, lines, foreas_name, subject)
    }

if os.path.exists(output_file):
    df_progress = pd.read_csv(output_file)
    processed_adas = set(df_progress['ada'].tolist())
    results = df_progress.to_dict('records')
    print(f"📦 Συνέχεια από checkpoint: {len(processed_adas)} έγγραφα ήδη έτοιμα.")
else:
    processed_adas = set()
    results = []
    print("🚀 Πλήρης επανεπεξεργασία όλων των PDF με την τελική, δοκιμασμένη λογική...")

headers = {'User-Agent': 'Mozilla/5.0'}
total_docs = len(df_payments)

for index, row in df_payments.iterrows():
    ada = row['ada']
    if ada in processed_adas:
        continue
    url = row['documentUrl']
    foreas_name = row.get('foreas_name', '') if hasattr(row, 'get') else ''
    subject = row.get('subject', '') if hasattr(row, 'get') else ''
    fields = {'amount_net': "Δεν βρέθηκε", 'amount_gross': "Δεν βρέθηκε",
              'assignment_type': "Σφάλμα", 'contractor_name': "Σφάλμα"}
    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code == 200:
            with io.BytesIO(response.content) as f:
                reader = pypdf.PdfReader(f)
                text = "".join([p.extract_text() or "" for p in reader.pages])
                fields = process_pdf_text(text, foreas_name, subject)
        else:
            fields = {'amount_net': "Σφάλμα Λήψης", 'amount_gross': "Σφάλμα Λήψης",
                       'assignment_type': "Σφάλμα", 'contractor_name': "Σφάλμα"}
    except Exception:
        fields = {'amount_net': "Σφάλμα Ανάγνωσης", 'amount_gross': "Σφάλμα Ανάγνωσης",
                   'assignment_type': "Σφάλμα", 'contractor_name': "Σφάλμα"}

    row_dict = row.to_dict()
    row_dict.update(fields)
    results.append(row_dict)
    processed_adas.add(ada)

    if len(results) % 50 == 0:
        pd.DataFrame(results).to_csv(output_file, index=False, encoding='utf-8-sig')
        print(f"⏳ {len(results)}/{total_docs} | net: {fields['amount_net']} | ανάδοχος: {str(fields['contractor_name'])[:35]}")
        time.sleep(0.3)

pd.DataFrame(results).to_csv(output_file, index=False, encoding='utf-8-sig')
print("✅ Ολοκληρώθηκε το τελικό rebuild!")

# %%
# ============================================================
# ΓΡΗΓΟΡΟΣ ΕΛΕΓΧΟΣ ΠΟΙΟΤΗΤΑΣ (πριν προχωρησουμε σε καθαρισμο/αναλυση)
# ============================================================
import pandas as pd

df = pd.read_csv('diavgeia_final_extracted_v3.csv')
n = len(df)

print(f"Σύνολο εγγραφών: {n}\n")

print("--- Ποσοστό εγγραφών χωρίς εύρημα ---")
print(f"Χωρίς καθαρό ποσό:  {(df['amount_net'].isin(['Δεν βρέθηκε'])).sum()} ({(df['amount_net'].isin(['Δεν βρέθηκε'])).mean():.1%})")
print(f"Χωρίς συνολικό ποσό: {(df['amount_gross'].isin(['Δεν βρέθηκε'])).sum()} ({(df['amount_gross'].isin(['Δεν βρέθηκε'])).mean():.1%})")
print(f"Χωρίς ανάδοχο:        {(df['contractor_name'] == 'Δεν εντοπίστηκε').sum()} ({(df['contractor_name'] == 'Δεν εντοπίστηκε').mean():.1%})")

print("\n--- Κατανομή τρόπου ανάθεσης ---")
print(df['assignment_type'].value_counts())

# Sanity check: όπου έχουμε ΚΑΙ net ΚΑΙ gross, το gross πρέπει να είναι >= net
def to_float(s):
    try:
        return float(str(s).replace('.', '').replace(',', '.'))
    except (ValueError, TypeError):
        return None

both = df[~df['amount_net'].isin(['Δεν βρέθηκε']) & ~df['amount_gross'].isin(['Δεν βρέθηκε'])].copy()
both['net_f'] = both['amount_net'].apply(to_float)
both['gross_f'] = both['amount_gross'].apply(to_float)
violations = both[both['net_f'] > both['gross_f']]
print(f"\n--- Λογικός έλεγχος: gross >= net ---")
print(f"Εγγραφές όπου ΤΟ ΚΑΘΑΡΟ ξεπερνά το συνολικό (πρόβλημα προς έλεγχο): {len(violations)} / {len(both)}")
if len(violations) > 0:
    display(violations[['ada', 'amount_net', 'amount_gross']].head(10))

print("\n--- Τυχαίο δείγμα 5 εγγραφών για χειροκίνητο έλεγχο ---")
display(df.sample(min(5, n))[['ada', 'subject', 'amount_net', 'amount_gross', 'contractor_name', 'assignment_type', 'documentUrl']])

# %%
# ============================================================
# ΚΑΘΑΡΙΣΜΟΣ & ΤΕΛΙΚΟ DATASET
#
# Στρατηγικη: δεν χρειαζεται να σωσουμε ΚΑΘΕ εγγραφη -- η εργασια ζητα
# ελαχιστο 500, εμεις εχουμε 8.273. Προτιμαμε ΛΙΓΟΤΕΡΕΣ αλλα ΑΞΙΟΠΙΣΤΕΣ.
#
# 1) Καθαρισμος "ψευτο-θετικων" στον αναδοχο: μερικες φορες ο κωδικας
#    εβρισκε κατι (οχι "Δεν εντοπίστηκε") αλλα ηταν σκουπιδι (π.χ.
#    "ΒΕΒΑΙΩΣΗ ΚΙΝΗΣΗΣ", "ΑΣΦΑΛΙΣΤΙΚΗ ΕΝΗΜΕΡΟΤΗΤΑ", κομματια λεξεων).
#    Αυτα τα ξανακανουμε "Δεν εντοπίστηκε" (ειλικρινης αγνοια > ψευτος
#    θετικος). Δεν χρειαζεται να ξαναβγουμε στα PDF -- δουλευουμε πανω
#    στο ηδη υπαρχον CSV.
# 2) "Αξιοπιστο ποσο" = εχει ΚΑΙ καθαρο ΚΑΙ συνολικο ποσο, και τα δυο
#    περνανε τον λογικο ελεγχο (καθαρο <= συνολικο). Ο αναδοχος ΔΕΝ
#    ειναι κριτηριο αποκλεισμου (δεν ειναι υποχρεωτικο πεδιο) -- τον
#    κραταμε ως bonus στηλη.
# ============================================================
import pandas as pd
import re

df = pd.read_csv('diavgeia_final_extracted_v3.csv')
print(f"Ξεκιναμε με {len(df)} εγγραφες.")

# --- Καθαρισμος "ψευτο-θετικων" στο ονομα αναδοχου ---
GARBAGE_PATTERNS = ['ΤΑΚΤΙ', 'Κ.Α.Ε', 'ΑΣΦΑΛΙΣΤΙΚΗ ΕΝΗΜΕΡΟΤΗΤΑ', 'ΒΕΒΑΙΩΣΗ', 'ΚΑΘ ΑΞΙΑ',
                    'ΚΑΘ. ΑΞΙΑ', 'ΚΑΘΑΡΗ ΑΞΙΑ', 'ΠΕΡΙΓΡΑΦΗ ΛΟΓΑΡΙΑΣΜΟΥ', 'ΚΑΤΗΓ',
                    'ΔΙΚΑΙΟΛΟΓΗΤΙΚΑ', 'ΛΟΓΑΡΙΑΣΜΟΥ', 'ΠΕΡΙΓΡΑΦΗ', 'Φ.Π.Α',
                    'ΥΠΕΡ ΤΡΙΤΩΝ', 'ΕΛΛΗΝΙΚΗ ΔΗΜΟΚΡ', 'ΕΛΛΗΝΙΚΗ ΔΗΜΟΚΡΑΤΙΑ',
                    'ΠΡΟΥΠΟΛΟΓΙΣΜΟ', 'ΦΥΛΛΟ ΕΚΚΑΘΑΡΙΣΗΣ', 'ΣΕΙΡΑ : Α', 'ΣΕΙΡΑ :Α',
                    # Επιπλεον garbage που εντοπιστηκε μετα τον ελεγχο του dataset:
                    'ΕΚΘ. ΑΝΑΛ', 'ΕΚΘΕΣΗ ΑΝΑΛ', 'ΑΝΑΛΥΣΗΣ ΔΑΠΑΝΗΣ',  # επικεφαλιδες πινακα
                    'ΚΩΔΙΚΟΣ ΔΙΑΜΟΡΦΩΘΕΝΤΑ', 'ΕΝΤΑΛΘΕΝΤΑ ΜΕ ΤΟ ΠΑΡΟΝ',  # επικεφαλιδα πινακα
                    'ΕΛΕΓΚΤΙΚΟ ΣΥΝΕΔΡΙΟ',   # boilerplate κειμενου
                    'ΔΗΜΟΣ ΚΕΝΤΡΙΚΗΣ ΚΕΡΚΥΡ', 'ΔΗΜΟΣ ΑΡΓΟΥΣ', 'ΔΗΜΟΣ ΝΙΚΑΙΑΣ',
                    'ΔΗΜΟΣ ΓΛΥΦΑΔ', 'ΔΗΜΟΣ ΧΑΝΙ', 'ΔΗΜΟΣ ΠΑΥΛΟΥ',  # δημοι ως αναδοχοι = λαθος
                    '|SA |', 'ΔΗΜ. ΣΥΜΒ.',  # κομματια πινακα
                    'ΚΩΔ.-ΛΟΓ/ΣΜΟΣ', 'ΛΟΓ/ΣΜΟΣ-ΠΑΡ/ΚΟ',  # επικεφαλιδες πινακα
                    'ΑΠΟΦΑΣΗ ΑΝΑΘΕΣΗΣ ΔΗΜΑΡΧΟΥ', 'ΑΠΟΦΑΣΗ ΔΗΜΑΡΧΟΥ',  # boilerplate
                    'ΤΑΜΕΙΟ ΠΑΡ', 'ΠΑΡΑΚΑΤΑΘΗΚΩΝ']  # Ταμειο Παρακαταθηκων, οχι εργολαβος

def clean_contractor(name):
    if pd.isna(name) or str(name).strip() == '':
        return 'Δεν εντοπίστηκε'
    name_up = str(name).upper()
    if any(p in name_up for p in GARBAGE_PATTERNS):
        return 'Δεν εντοπίστηκε'
    words = str(name).split()
    if len(words) == 1 and len(str(name)) < 10 and not re.search(r'(Ο\.?Ε\.?|Α\.?Ε\.?|ΕΠΕ|ΙΚΕ)$', name_up):
        return 'Δεν εντοπίστηκε'
    return name

before_found = (df['contractor_name'] != 'Δεν εντοπίστηκε').sum()
df['contractor_name'] = df['contractor_name'].apply(clean_contractor)
after_found = (df['contractor_name'] != 'Δεν εντοπίστηκε').sum()
print(f"Ανάδοχος -- πριν καθαρισμα: {before_found}, μετα: {after_found} "
      f"(αφαιρεθηκαν {before_found - after_found} 'ψευτο-θετικα')")

# --- Μετατροπη ποσων σε πραγματικους αριθμους ---
def to_float(s):
    try:
        return float(str(s).replace('.', '').replace(',', '.'))
    except (ValueError, TypeError):
        return None

df['amount_net_eur'] = df['amount_net'].apply(to_float)
df['amount_gross_eur'] = df['amount_gross'].apply(to_float)

# --- Ετος / Μηνας απο το issueDate ---
df['issue_date_parsed'] = pd.to_datetime(df['issueDate'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
df['year'] = df['issue_date_parsed'].dt.year
df['month'] = df['issue_date_parsed'].dt.month

# --- Σημαια αξιοπιστιας ποσου ---
# Χρησιμοποιουμε ΜΟΝΟ το καθαρο/πληρωτεο ποσο (amount_net_eur) ως κυριο ποσο.
# Λογοι: (1) εξαγεται πιο αξιοπιστα (η ετικετα "ΠΛΗΡΩΤΕΟ ΠΟΣΟ" εμφανιζεται
# συνεπως σε ολα τα templates), (2) ειναι αυτο που πραγματικα πληρωθηκε,
# (3) το gross σε ~55% των εγγραφων ταυτιζεται με το net λογω συγχυσης
# στην εξαγωγη (διμερης στηλη στο PDF αναποδογυριζει τη σειρα των τιμων).
# Η διαφορα gross-net (κρατησεις) ειναι ~5% συνολικα -- αμελητεα για
# δημοσιογραφικη αναλυση, αλλα αναφερεται ως περιορισμος στο αρθρο.
ok_download = df['assignment_type'] != 'Σφάλμα'
has_net = df['amount_net_eur'].notna()
df['reliable_amount'] = ok_download & has_net

print(f"\nΑξιοπιστο ποσο (εχει καθαρο/πληρωτεο ποσο): {df['reliable_amount'].sum()} / {len(df)}")
print(f"Εχουν επιπλεον και (καθαρισμενο) ανάδοχο: {(df['reliable_amount'] & (df['contractor_name']!='Δεν εντοπίστηκε')).sum()}")

# --- Κραταμε μονο τις αξιοπιστες ---
df_clean = df[df['reliable_amount']].copy()
before = len(df_clean)

# Βημα Α: Αφαιρεση μηδενικων ποσων (σφαλματα εξαγωγης)
df_clean = df_clean[df_clean['amount_net_eur'] > 0]
print(f"Αφαιρεθηκαν μηδενικα ποσα: {before - len(df_clean)}")

# Βημα Β: Αφαιρεση κεντρικων φορεων (οχι δημοι -- εκτος θεματος)
before2 = len(df_clean)
df_clean = df_clean[~df_clean['foreas_name'].str.contains('ΚΤΙΡΙΑΚΕΣ ΥΠΟΔΟΜΕΣ', na=False)]
print(f"Αφαιρεθηκαν κεντρικοι φορεις (ΚΤΙΡΙΑΚΕΣ ΥΠΟΔΟΜΕΣ ΑΕ): {before2 - len(df_clean)}")

# Βημα Γ: Αφαιρεση ποσων < 1€ (τραπεζικα εξοδα/σφαλματα, οχι πραγματικες εργασιες)
before3 = len(df_clean)
df_clean = df_clean[df_clean['amount_net_eur'] >= 1.0]
print(f"Αφαιρεθηκαν ποσα < 1€ (σφαλματα): {before3 - len(df_clean)}")

# Βημα Δ: Αφαιρεση διπλοτυπων ΑΔΑ
before4 = len(df_clean)
df_clean = df_clean.drop_duplicates(subset=['ada'])
print(f"Αφαιρεθηκαν διπλοτυπα ΑΔΑ: {before4 - len(df_clean)}")

# Βημα Ε: Αφαιρεση διπλοτυπων (ιδιος δημος + ποσο + ημερομηνια = ανατυπωμενα εντυπα)
before5 = len(df_clean)
df_clean = df_clean.drop_duplicates(subset=['foreas_name', 'amount_net_eur', 'issueDate'], keep='first')
print(f"Αφαιρεθηκαν διπλοτυπα (δημος+ποσο+ημερομηνια): {before5 - len(df_clean)}")

print(f"\nΣυνολο αφαιρεθεντων: {before - len(df_clean)} | Απομενουν: {len(df_clean)}")

# --- Κραταμε μονο τις χρησιμες στηλες για το τελικο dataset ---
final_cols = ['ada', 'issueDate', 'year', 'month', 'subject', 'foreas_name',
              'organization', 'decisionType', 'amount_net_eur',
              'assignment_type', 'contractor_name', 'documentUrl']
df_final = df_clean[final_cols].rename(columns={
    'subject': 'titlos_apofasis',
    'amount_net_eur': 'poso_eur',   # καθαρο/πληρωτεο ποσο -- η μοναδικη στηλη ποσου
})

df_final.to_csv('diavgeia_TELIKO_dataset.csv', index=False, encoding='utf-8-sig')
print(f"\n✅ Τελικο dataset: {len(df_final)} εγγραφες -> diavgeia_TELIKO_dataset.csv")
print(f"   (ελαχιστο απαιτουμενο απο την εκφωνηση: 500)")
print(f"\nΚατανομη ανα ετος:")
print(df_final['year'].value_counts().sort_index())
print(f"\nΤυχαιο δειγμα 8 εγγραφων για χειροκινητο ελεγχο:")
display(df_final.sample(8, random_state=42)[['ada','titlos_apofasis','poso_eur','contractor_name','year','documentUrl']])

# %%
# ============================================================
# ΑΝΑΛΥΣΗ ΔΕΔΟΜΕΝΩΝ ΣΕ PYTHON
#
# Αυτο το κελι δειχνει ολη την αναλυση που απαιτει η εκφωνηση:
# - groupby ανα ετος, μηνα, δημο, αναδοχο
# - νεες στηλες που βοηθουν την αναλυση (κατηγορια, size_category)
# - μεγαλυτερες αποφασεις
# - συχνοτερες λεξεις στους τιτλους
# ============================================================
import pandas as pd
import re
from collections import Counter

df = pd.read_csv('diavgeia_TELIKO_dataset.csv')
print(f"Dataset: {len(df)} εγγραφες | Περιοδος: {int(df['year'].min())}-{int(df['year'].max())}")
print(f"Συνολο αξια: €{df['poso_eur'].sum():,.0f} | Μεσος ορος: €{df['poso_eur'].mean():,.0f} | Διαμεσος: €{df['poso_eur'].median():,.0f}")

# --- Νεα στηλη: κατηγορια αποφασης ---
def categorize(title):
    t = str(title).upper()
    if any(w in t for w in ['ΑΝΑΚΑΙΝΙΣ', 'ΑΝΑΒΑΘΜΙΣ', 'ΕΝΕΡΓΕΙΑΚ']):
        return 'Ανακαίνιση / Ενεργειακή Αναβάθμιση'
    if any(w in t for w in ['ΕΠΙΣΚΕΥ', 'ΑΠΟΚΑΤΑΣ']):
        return 'Επισκευή'
    if any(w in t for w in ['ΣΥΝΤΗΡ']):
        return 'Συντήρηση'
    if any(w in t for w in ['ΠΡΟΜΗΘ']):
        return 'Προμήθεια Υλικών'
    if any(w in t for w in ['ΕΠΙΧΟΡΗΓ', 'ΧΡΗΜΑΤΟΔΟΤ', 'ΑΠΟΔΟΣΗ']):
        return 'Επιχορήγηση / Χρηματοδότηση'
    if any(w in t for w in ['ΜΙΣΘ', 'ΑΜΟΙΒ']):
        return 'Αμοιβή / Μισθοδοσία'
    return 'Λοιπά'

df['kategoria'] = df['titlos_apofasis'].apply(categorize)

# --- Νεα στηλη: μεγεθος πληρωμης ---
def size_cat(v):
    if v < 1000: return 'Α. Κάτω από €1.000'
    if v < 5000: return 'Β. €1.000 - €5.000'
    if v < 20000: return 'Γ. €5.000 - €20.000'
    if v < 50000: return 'Δ. €20.000 - €50.000'
    return 'Ε. Άνω από €50.000'

df['size_category'] = df['poso_eur'].apply(size_cat)

# Αποθηκευση του εμπλουτισμενου dataset
df.to_csv('diavgeia_TELIKO_dataset.csv', index=False, encoding='utf-8-sig')
print("\n✅ Dataset εμπλουτιστηκε με στηλες 'kategoria' και 'size_category'")

print("\n" + "="*55)
print("1. ΤΑΣΕΙΣ ΑΝΑ ΕΤΟΣ (2014-2025)")
print("="*55)
by_year = df[df['year'] <= 2025].groupby('year').agg(
    apofaseis=('ada', 'count'),
    synoliko_poso_eur=('poso_eur', 'sum'),
    meso_poso_eur=('poso_eur', 'mean')
).round(0).astype(int)
display(by_year)

print("\n" + "="*55)
print("2. TOP 15 ΔΗΜΟΙ ΑΝΑ ΣΥΝΟΛΙΚΟ ΠΟΣΟ")
print("="*55)
top_foreas_poso = df.groupby('foreas_name').agg(
    apofaseis=('ada', 'count'),
    synoliko_poso_eur=('poso_eur', 'sum')
).sort_values('synoliko_poso_eur', ascending=False).head(15)
top_foreas_poso['synoliko_poso_eur'] = top_foreas_poso['synoliko_poso_eur'].round(0).astype(int)
display(top_foreas_poso)

print("\n" + "="*55)
print("3. TOP 15 ΔΗΜΟΙ ΑΝΑ ΑΡΙΘΜΟ ΑΠΟΦΑΣΕΩΝ")
print("="*55)
top_foreas_count = df.groupby('foreas_name').agg(
    apofaseis=('ada', 'count'),
    synoliko_poso_eur=('poso_eur', 'sum')
).sort_values('apofaseis', ascending=False).head(15)
top_foreas_count['synoliko_poso_eur'] = top_foreas_count['synoliko_poso_eur'].round(0).astype(int)
display(top_foreas_count)

print("\n" + "="*55)
print("4. ΜΗΝΙΑΙΑ ΚΑΤΑΝΟΜΗ ΑΠΟΦΑΣΕΩΝ (ολα τα ετη)")
print("="*55)
months_gr = {1:'Ιαν',2:'Φεβ',3:'Μαρ',4:'Απρ',5:'Μαι',6:'Ιουν',
             7:'Ιουλ',8:'Αυγ',9:'Σεπ',10:'Οκτ',11:'Νοε',12:'Δεκ'}
by_month = df.groupby('month').agg(
    apofaseis=('ada', 'count'),
    synoliko_poso_eur=('poso_eur', 'sum')
).round(0)
by_month.index = by_month.index.map(months_gr)
display(by_month)

print("\n" + "="*55)
print("5. ΚΑΤΑΝΟΜΗ ΑΝΑ ΚΑΤΗΓΟΡΙΑ ΑΠΟΦΑΣΗΣ")
print("="*55)
by_kat = df.groupby('kategoria').agg(
    apofaseis=('ada', 'count'),
    synoliko_poso_eur=('poso_eur', 'sum')
).sort_values('synoliko_poso_eur', ascending=False)
by_kat['synoliko_poso_eur'] = by_kat['synoliko_poso_eur'].round(0).astype(int)
display(by_kat)

print("\n" + "="*55)
print("6. ΚΑΤΑΝΟΜΗ ΑΝΑ ΜΕΓΕΘΟΣ ΠΛΗΡΩΜΗΣ")
print("="*55)
by_size = df.groupby('size_category').agg(
    apofaseis=('ada', 'count'),
    synoliko_poso_eur=('poso_eur', 'sum')
).sort_index()
by_size['synoliko_poso_eur'] = by_size['synoliko_poso_eur'].round(0).astype(int)
display(by_size)

print("\n" + "="*55)
print("7. ΟΙ 10 ΜΕΓΑΛΥΤΕΡΕΣ ΑΠΟΦΑΣΕΙΣ")
print("="*55)
top10 = df.nlargest(10, 'poso_eur')[['ada','year','titlos_apofasis','foreas_name','poso_eur','contractor_name']]
top10['poso_eur'] = top10['poso_eur'].round(0).astype(int)
display(top10)

print("\n" + "="*55)
print("8. TOP 15 ΑΝΑΔΟΧΟΙ (σε εγγραφες με αναδοχο)")
print("="*55)
has_contractor = df[df['contractor_name'] != 'Δεν εντοπίστηκε']
top_contractors = has_contractor.groupby('contractor_name').agg(
    anatheseis=('ada', 'count'),
    synoliko_poso_eur=('poso_eur', 'sum')
).sort_values('synoliko_poso_eur', ascending=False).head(15)
top_contractors['synoliko_poso_eur'] = top_contractors['synoliko_poso_eur'].round(0).astype(int)
display(top_contractors)

print("\n" + "="*55)
print("9. ΣΥΧΝΟΤΕΡΕΣ ΛΕΞΕΙΣ ΣΤΟΥΣ ΤΙΤΛΟΥΣ (top 20)")
print("="*55)
stopwords = {'ΚΑΙ','ΤΟΥ','ΤΗΣ','ΤΩΝ','ΤΟ','ΤΑ','ΤΗΝ','ΤΟΝ','ΣΤΟ','ΣΤΑ','ΣΤΗ','ΣΤΟΝ',
             'ΑΠΟ','ΓΙΑ','ΜΕ','ΩΣ','ΤΕ','ΕΠΙ','ΠΡΟ','ΕΙΣ','ΑΝΑ','ΔΕ','ΜΗ','ΤΕ',
             'ΕΝ','Η','Ο','ΟΙ','ΣΕ','ΤΕ','ΝΑ','ΤΙ','Α','Β','Γ'}
all_words = []
for title in df['titlos_apofasis'].dropna():
    words = re.findall(r'[Α-ΩΪΫΆΈΉΊΌΎΏΐΰα-ωϊϋάέήίόύώ]{4,}', str(title).upper())
    all_words.extend([w for w in words if w not in stopwords])
word_freq = Counter(all_words).most_common(20)
word_df = pd.DataFrame(word_freq, columns=['λεξη', 'συχνοτητα'])
display(word_df)


print("\n" + "="*55)
print("10. ΣΥΓΚΡΙΣΗ ΔΑΠΑΝΩΝ ΠΡΙ/ΜΕΤΑ ΤΟ 2020 ΑΝΑ ΔΗΜΟ")
print("="*55)
print("Εντοπισμος δημων με εκρηκτικη αυξηση μετα το 2020")
print("ΣΗΜΕΙΩΣΗ: χρονικη συσχετιση με Ταμειο Ανακαμψης/ΕΣΠΑ 2021-2027,")
print("οχι αποδεδειγμενη αιτιακη σχεση (η πηγη δεν αναγραφεται στα εγγραφα)")

pre_2020 = df[df['year'] < 2020].groupby('foreas_name')['poso_eur'].sum()
post_2020 = df[df['year'] >= 2020].groupby('foreas_name')['poso_eur'].sum()
compare = pd.DataFrame({'pre_2020': pre_2020, 'post_2020': post_2020}).dropna()
compare = compare[compare['pre_2020'] > 10000]
compare['auxisi_pct'] = ((compare['post_2020'] - compare['pre_2020']) / compare['pre_2020'] * 100).round(0)
top_growth = compare.sort_values('auxisi_pct', ascending=False).head(10).copy()
top_growth['pre_2020'] = top_growth['pre_2020'].round(0).astype(int)
top_growth['post_2020'] = top_growth['post_2020'].round(0).astype(int)
top_growth['auxisi_pct'] = top_growth['auxisi_pct'].astype(int)
display(top_growth)

print("\n--- Εγγραφες 2026 (ατελες ετος, εως Μαιο 2026) ---")
df_2026 = df[df['year'] == 2026]
print(f"Πληθος: {len(df_2026)} εντάλματα | Συνολο: €{df_2026['poso_eur'].sum():,.0f}")

print("\n✅ Αναλυση ολοκληρωθηκε. Τα δεδομενα ειναι ετοιμα για γραφηματα (Datawrapper).")
